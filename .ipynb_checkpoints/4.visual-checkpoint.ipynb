# %%
import pandas as pd
from pyecharts import Bar
from pyecharts import Line,  Overlap, Style

# %%
df = pd.read_csv(r'C:\DATA\KB_capstone\corr_table\corr_table.csv', engine = 'c')

# %%
df.index = df['variable_name']

# %%
df = df.iloc[:,2:]

# %%
df = df.dropna()

# %%
var = df.T.var()*1000
average = df.T.mean()

# %%
df['var'] = var
df['mean'] = average

# %%
df.sort_values(['var'], ascending = False)
# Out:
#                                                        분식집       양식집  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR          0.063474  0.273555
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR              0.142927  0.198989
# 패스트푸드점_점포수의__STOR_CO vs SELNG_PRER_STOR           0.059935  0.043303
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.217315  0.208538
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.212258  0.199897
# STOR_CO vs SELNG_PRER_STOR                        0.131738  0.209544
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.211227  0.202448
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR             0.224948  0.211349
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.136506  0.114081
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.201460  0.196530
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.201569  0.185431
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.099498  0.133423
# INCOME_SCTN_CD vs SELNG_PRER_STOR                 0.217234  0.206285
# THEAT_CO vs SELNG_PRER_STOR                       0.149597  0.156182
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.212749  0.163285
# 분식집_STOR_CO vs SELNG_PRER_STOR                    0.123595  0.003458
# 일식집_STOR_CO vs SELNG_PRER_STOR                    0.158147  0.031669
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.200066  0.125684
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                  0.178871  0.057630
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR           0.146083  0.136487
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.171834  0.117464
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.212222  0.142614
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.098461  0.073234
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR      0.208641  0.138186
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR      0.135183  0.131926
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                0.061005  0.197502
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.213116  0.135373
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR              0.071446  0.201525
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.210401  0.215804
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                 0.185568  0.119340
# ...                                                    ...       ...
# 정육점_STOR_CO vs SELNG_PRER_STOR                   -0.147209 -0.164696
# FAG_10_SUNTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.046053  0.004639
# MAG_60_ABOVE_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.076317 -0.133546
# MAG_60_ABOVE_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.089328 -0.138216
# FAG_10_SUNTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.038533  0.046479
# FAG_10_SUNTM_5_FLPOP_CO vs SELNG_PRER_STOR        0.078373  0.038055
# 중국집_점포수의__STOR_CO vs SELNG_PRER_STOR              0.093769  0.050690
# FAG_10_TUETM_6_FLPOP_CO vs SELNG_PRER_STOR        0.043605  0.010008
# MAG_10_THUTM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.004077  0.002094
# PC방_STOR_CO vs SELNG_PRER_STOR                    0.055604  0.056187
# FAG_10_THUTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.052059  0.014712
# FAG_10_SATTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.055073  0.007786
# UNIV_CO vs SELNG_PRER_STOR                        0.025313  0.056344
# FAG_10_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR       -0.003101 -0.058696
# MAG_10_FRITM_3_FLPOP_RATIO vs SELNG_PRER_STOR     0.005570  0.001778
# FAG_10_SUNTM_6_FLPOP_RATIO vs SELNG_PRER_STOR    -0.001323  0.001452
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR           0.144139  0.112357
# FAG_10_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR    -0.048335 -0.066371
# MAG_30_SUNTM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.043822 -0.032317
# FAG_10_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR        0.002907 -0.049697
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR             -0.140389 -0.152714
# FAG_10_SATTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.072510  0.078928
# DAY_WED_FLPOP_RATIO vs SELNG_PRER_STOR            0.090945  0.097378
# FAG_10_SUNTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.049229  0.058294
# FAG_10_SATTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.062775  0.079329
# FAG_10_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.002056  0.006946
# 부동산중개업_STOR_CO vs SELNG_PRER_STOR                 0.033936  0.032113
# HGSCHL_CO vs SELNG_PRER_STOR                     -0.003604 -0.003829
# GNRL_HSPTL_CO vs SELNG_PRER_STOR                  0.018395  0.030742
# PBLOFC_CO vs SELNG_PRER_STOR                      0.044938  0.074539
#
#                                                        일식집       제과점  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR          0.159865  0.249728
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR              0.027444  0.059691
# 패스트푸드점_점포수의__STOR_CO vs SELNG_PRER_STOR           0.052700 -0.024070
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.175348  0.089337
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.170990  0.087914
# STOR_CO vs SELNG_PRER_STOR                        0.125063  0.065783
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.165723  0.085950
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR             0.184658  0.169926
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.114562  0.051031
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.162526  0.086247
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.163836  0.076477
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.075446  0.110474
# INCOME_SCTN_CD vs SELNG_PRER_STOR                 0.190517  0.168040
# THEAT_CO vs SELNG_PRER_STOR                       0.063028  0.043107
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.162179  0.120529
# 분식집_STOR_CO vs SELNG_PRER_STOR                    0.074464  0.070833
# 일식집_STOR_CO vs SELNG_PRER_STOR                    0.108468  0.107134
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.148133  0.078534
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                  0.113530  0.050139
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR           0.139085  0.078785
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.141046  0.083556
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.170044  0.146365
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.021498  0.112915
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR      0.150612  0.094866
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR      0.122329  0.098254
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                0.041916  0.072335
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.149047  0.090578
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR              0.030267  0.057971
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.176451  0.139913
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                 0.136099  0.072287
# ...                                                    ...       ...
# 정육점_STOR_CO vs SELNG_PRER_STOR                   -0.150552 -0.149187
# FAG_10_SUNTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.032150  0.024816
# MAG_60_ABOVE_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.070283 -0.078757
# MAG_60_ABOVE_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.084677 -0.087340
# FAG_10_SUNTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.011167  0.038054
# FAG_10_SUNTM_5_FLPOP_CO vs SELNG_PRER_STOR        0.047630  0.039321
# 중국집_점포수의__STOR_CO vs SELNG_PRER_STOR              0.043655  0.062524
# FAG_10_TUETM_6_FLPOP_CO vs SELNG_PRER_STOR        0.035963  0.038114
# MAG_10_THUTM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.036343  0.023164
# PC방_STOR_CO vs SELNG_PRER_STOR                    0.002569  0.035127
# FAG_10_THUTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.040379  0.038568
# FAG_10_SATTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.030736  0.025402
# UNIV_CO vs SELNG_PRER_STOR                        0.074867  0.034054
# FAG_10_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR       -0.011059 -0.021521
# MAG_10_FRITM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.033070  0.021771
# FAG_10_SUNTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.009636  0.025889
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR           0.105373  0.106502
# FAG_10_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR    -0.029062 -0.019536
# MAG_30_SUNTM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.031648 -0.018464
# FAG_10_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR       -0.001021 -0.013122
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR             -0.118449 -0.153544
# FAG_10_SATTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.050223  0.060382
# DAY_WED_FLPOP_RATIO vs SELNG_PRER_STOR            0.079360  0.088030
# FAG_10_SUNTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.035870  0.050939
# FAG_10_SATTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.051773  0.061002
# FAG_10_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.010127  0.022828
# 부동산중개업_STOR_CO vs SELNG_PRER_STOR                 0.011959  0.001388
# HGSCHL_CO vs SELNG_PRER_STOR                      0.016381 -0.010811
# GNRL_HSPTL_CO vs SELNG_PRER_STOR                  0.028475  0.027639
# PBLOFC_CO vs SELNG_PRER_STOR                      0.059367  0.054529
#
#                                                        중국집       치킨집  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR          0.064676  0.117714
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR              0.049721 -0.027799
# 패스트푸드점_점포수의__STOR_CO vs SELNG_PRER_STOR           0.073473  0.060110
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.233693  0.173461
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.241977  0.172706
# STOR_CO vs SELNG_PRER_STOR                        0.035784  0.061177
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.235574  0.171618
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR             0.318169  0.180018
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.256719  0.149240
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.234072  0.166557
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.234609  0.165311
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.251638  0.125072
# INCOME_SCTN_CD vs SELNG_PRER_STOR                 0.299399  0.161231
# THEAT_CO vs SELNG_PRER_STOR                       0.093450 -0.011130
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.252087  0.147809
# 분식집_STOR_CO vs SELNG_PRER_STOR                    0.094856  0.194421
# 일식집_STOR_CO vs SELNG_PRER_STOR                    0.112150  0.137287
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.222479  0.137384
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                  0.089767  0.208274
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR           0.217596  0.090068
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.213152  0.106505
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.247813  0.170774
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.201417  0.098404
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR      0.218853  0.151152
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR      0.277733  0.126075
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                0.026796  0.046109
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.212399  0.160041
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR              0.031485  0.055470
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.260051  0.136129
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                 0.195888  0.126496
# ...                                                    ...       ...
# 정육점_STOR_CO vs SELNG_PRER_STOR                   -0.125316 -0.098432
# FAG_10_SUNTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.051669  0.083455
# MAG_60_ABOVE_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.088505 -0.057538
# MAG_60_ABOVE_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.100987 -0.066738
# FAG_10_SUNTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.037556  0.036108
# FAG_10_SUNTM_5_FLPOP_CO vs SELNG_PRER_STOR        0.067156  0.091857
# 중국집_점포수의__STOR_CO vs SELNG_PRER_STOR              0.090915  0.062898
# FAG_10_TUETM_6_FLPOP_CO vs SELNG_PRER_STOR        0.058804  0.084779
# MAG_10_THUTM_3_FLPOP_RATIO vs SELNG_PRER_STOR     0.009004  0.021359
# PC방_STOR_CO vs SELNG_PRER_STOR                    0.082161  0.062928
# FAG_10_THUTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.061442  0.090708
# FAG_10_SATTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.051159  0.080807
# UNIV_CO vs SELNG_PRER_STOR                        0.042024  0.013837
# FAG_10_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR        0.007727  0.020021
# MAG_10_FRITM_3_FLPOP_RATIO vs SELNG_PRER_STOR     0.008086  0.025297
# FAG_10_SUNTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.039362  0.053664
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR           0.172514  0.134552
# FAG_10_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR    -0.026054 -0.019798
# MAG_30_SUNTM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.064269 -0.034104
# FAG_10_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR        0.001681  0.027380
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR             -0.111947 -0.115108
# FAG_10_SATTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.069750  0.050495
# DAY_WED_FLPOP_RATIO vs SELNG_PRER_STOR            0.141783  0.095924
# FAG_10_SUNTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.062662  0.057797
# FAG_10_SATTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.070717  0.064229
# FAG_10_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.035981  0.042789
# 부동산중개업_STOR_CO vs SELNG_PRER_STOR                 0.035326  0.016703
# HGSCHL_CO vs SELNG_PRER_STOR                      0.002154 -0.032969
# GNRL_HSPTL_CO vs SELNG_PRER_STOR                  0.021285  0.002525
# PBLOFC_CO vs SELNG_PRER_STOR                      0.079982  0.044980
#
#                                                       커피음료    패스트푸드점  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR          0.193213  0.018622
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR              0.164287  0.098018
# 패스트푸드점_점포수의__STOR_CO vs SELNG_PRER_STOR           0.091594 -0.133387
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.232169  0.111555
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.233897  0.112809
# STOR_CO vs SELNG_PRER_STOR                        0.213395  0.066289
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.229976  0.113719
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR             0.149115  0.139329
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.142404  0.051039
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.221037  0.113524
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.209438  0.107919
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.071231  0.033782
# INCOME_SCTN_CD vs SELNG_PRER_STOR                 0.165158  0.124631
# THEAT_CO vs SELNG_PRER_STOR                       0.153978  0.037231
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.158481  0.044886
# 분식집_STOR_CO vs SELNG_PRER_STOR                    0.136757  0.018856
# 일식집_STOR_CO vs SELNG_PRER_STOR                    0.193217  0.036491
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.125492  0.038501
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                  0.178715  0.046555
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR           0.122006  0.044530
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.107424  0.024694
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.159663  0.036880
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.046164  0.013317
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR      0.141822  0.039426
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR      0.151436  0.065403
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                0.150407  0.046886
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.137020  0.041781
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR              0.142697  0.053798
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.220722  0.126673
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                 0.123744  0.023811
# ...                                                    ...       ...
# 정육점_STOR_CO vs SELNG_PRER_STOR                   -0.114888 -0.160029
# FAG_10_SUNTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.060123  0.046436
# MAG_60_ABOVE_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.081541 -0.081977
# MAG_60_ABOVE_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.089254 -0.084913
# FAG_10_SUNTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.045232  0.055246
# FAG_10_SUNTM_5_FLPOP_CO vs SELNG_PRER_STOR        0.098982  0.072519
# 중국집_점포수의__STOR_CO vs SELNG_PRER_STOR              0.093207  0.082966
# FAG_10_TUETM_6_FLPOP_CO vs SELNG_PRER_STOR        0.062204  0.057798
# MAG_10_THUTM_3_FLPOP_RATIO vs SELNG_PRER_STOR     0.007226  0.022830
# PC방_STOR_CO vs SELNG_PRER_STOR                    0.060644  0.041779
# FAG_10_THUTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.069160  0.059981
# FAG_10_SATTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.067449  0.051566
# UNIV_CO vs SELNG_PRER_STOR                        0.074449  0.021439
# FAG_10_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR       -0.013318 -0.012793
# MAG_10_FRITM_3_FLPOP_RATIO vs SELNG_PRER_STOR     0.013702  0.025051
# FAG_10_SUNTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.020171  0.043462
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR           0.130490  0.115059
# FAG_10_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR    -0.067841 -0.028688
# MAG_30_SUNTM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.074396 -0.079656
# FAG_10_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR       -0.009546 -0.008398
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR             -0.116725 -0.120021
# FAG_10_SATTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.079067  0.085022
# DAY_WED_FLPOP_RATIO vs SELNG_PRER_STOR            0.092129  0.109691
# FAG_10_SUNTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.080133  0.079443
# FAG_10_SATTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.094605  0.091865
# FAG_10_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.028639  0.045429
# 부동산중개업_STOR_CO vs SELNG_PRER_STOR                 0.037884  0.028393
# HGSCHL_CO vs SELNG_PRER_STOR                     -0.014412 -0.006255
# GNRL_HSPTL_CO vs SELNG_PRER_STOR                  0.026517  0.023559
# PBLOFC_CO vs SELNG_PRER_STOR                      0.054654  0.055857
#
#                                                      한식음식점    호프간이주점  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR          0.156633  0.031832
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR             -0.005291 -0.002551
# 패스트푸드점_점포수의__STOR_CO vs SELNG_PRER_STOR           0.050066  0.103780
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.304147  0.272852
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.299510  0.272211
# STOR_CO vs SELNG_PRER_STOR                        0.175318  0.078117
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.294422  0.263072
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR             0.303528  0.279976
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.176635  0.201792
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.286607  0.260214
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.280220  0.249039
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.150025  0.185698
# INCOME_SCTN_CD vs SELNG_PRER_STOR                 0.301022  0.273737
# THEAT_CO vs SELNG_PRER_STOR                       0.148195  0.142306
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.245514  0.189444
# 분식집_STOR_CO vs SELNG_PRER_STOR                    0.063888  0.163505
# 일식집_STOR_CO vs SELNG_PRER_STOR                    0.199599  0.186030
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.221576  0.172502
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                  0.144064  0.161099
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR           0.209313  0.208327
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.210357  0.149223
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.217911  0.197161
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            0.105191  0.151357
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR      0.217581  0.181131
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR      0.117072  0.177124
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                0.083470  0.023727
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           0.211620  0.184944
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR              0.101104  0.039820
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.282253  0.251133
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                 0.198007  0.154792
# ...                                                    ...       ...
# 정육점_STOR_CO vs SELNG_PRER_STOR                   -0.120849 -0.127998
# FAG_10_SUNTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.033156  0.030800
# MAG_60_ABOVE_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.102644 -0.106138
# MAG_60_ABOVE_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR -0.118294 -0.120970
# FAG_10_SUNTM_4_FLPOP_RATIO vs SELNG_PRER_STOR    -0.002603 -0.006943
# FAG_10_SUNTM_5_FLPOP_CO vs SELNG_PRER_STOR        0.053463  0.050489
# 중국집_점포수의__STOR_CO vs SELNG_PRER_STOR              0.090851  0.108038
# FAG_10_TUETM_6_FLPOP_CO vs SELNG_PRER_STOR        0.028252  0.028813
# MAG_10_THUTM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.028586 -0.017233
# PC방_STOR_CO vs SELNG_PRER_STOR                    0.038067  0.042632
# FAG_10_THUTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.035190  0.039866
# FAG_10_SATTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.035799  0.045826
# UNIV_CO vs SELNG_PRER_STOR                        0.039983  0.031675
# FAG_10_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR       -0.026744 -0.010720
# MAG_10_FRITM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.027293 -0.012151
# FAG_10_SUNTM_6_FLPOP_RATIO vs SELNG_PRER_STOR    -0.003230  0.000700
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR           0.142337  0.123467
# FAG_10_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR    -0.072503 -0.046617
# MAG_30_SUNTM_3_FLPOP_RATIO vs SELNG_PRER_STOR    -0.039209 -0.059787
# FAG_10_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR       -0.027878 -0.013658
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR             -0.095643 -0.102971
# FAG_10_SATTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.040012  0.029374
# DAY_WED_FLPOP_RATIO vs SELNG_PRER_STOR            0.099619  0.082782
# FAG_10_SUNTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.036308  0.027880
# FAG_10_SATTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.052339  0.047325
# FAG_10_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.002503  0.020766
# 부동산중개업_STOR_CO vs SELNG_PRER_STOR                 0.051515  0.021428
# HGSCHL_CO vs SELNG_PRER_STOR                      0.015244  0.001907
# GNRL_HSPTL_CO vs SELNG_PRER_STOR                  0.046972 -0.002066
# PBLOFC_CO vs SELNG_PRER_STOR                      0.055089  0.053738
#
#                                                        var      mean
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR          7.926666  0.132931
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR              6.050477  0.070544
# 패스트푸드점_점포수의__STOR_CO vs SELNG_PRER_STOR           4.782563  0.037750
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     4.449305  0.201842
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     4.436489  0.200417
# STOR_CO vs SELNG_PRER_STOR                        4.216917  0.116221
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     4.172551  0.197373
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR             4.116250  0.216102
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        4.003544  0.139401
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR     3.908612  0.192877
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     3.888711  0.187385
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            3.880959  0.123629
# INCOME_SCTN_CD vs SELNG_PRER_STOR                 3.801984  0.210725
# THEAT_CO vs SELNG_PRER_STOR                       3.724557  0.097594
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             3.719747  0.169696
# 분식집_STOR_CO vs SELNG_PRER_STOR                    3.698637  0.094463
# 일식집_STOR_CO vs SELNG_PRER_STOR                    3.606003  0.127019
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           3.577261  0.147035
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                  3.556940  0.122864
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR           3.468560  0.139228
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        3.334945  0.132526
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             3.334154  0.170145
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR            3.311518  0.092196
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR      3.223523  0.154227
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR      3.211831  0.140253
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                3.182210  0.075015
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR           3.165863  0.153592
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR              3.045791  0.078559
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR     3.039637  0.201953
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                 3.038645  0.133603
# ...                                                    ...       ...
# 정육점_STOR_CO vs SELNG_PRER_STOR                    0.464102 -0.135916
# FAG_10_SUNTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.462655  0.041330
# MAG_60_ABOVE_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR  0.462122 -0.087724
# MAG_60_ABOVE_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR  0.461900 -0.098072
# FAG_10_SUNTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.461699  0.029883
# FAG_10_SUNTM_5_FLPOP_CO vs SELNG_PRER_STOR        0.459134  0.063784
# 중국집_점포수의__STOR_CO vs SELNG_PRER_STOR              0.459081  0.077951
# FAG_10_TUETM_6_FLPOP_CO vs SELNG_PRER_STOR        0.458929  0.044834
# MAG_10_THUTM_3_FLPOP_RATIO vs SELNG_PRER_STOR     0.455912 -0.000056
# PC방_STOR_CO vs SELNG_PRER_STOR                    0.452211  0.047770
# FAG_10_THUTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.449906  0.050206
# FAG_10_SATTM_6_FLPOP_CO vs SELNG_PRER_STOR        0.447348  0.045160
# UNIV_CO vs SELNG_PRER_STOR                        0.444831  0.041398
# FAG_10_SUNTM_1_FLPOP_CO vs SELNG_PRER_STOR        0.441853 -0.013020
# MAG_10_FRITM_3_FLPOP_RATIO vs SELNG_PRER_STOR     0.436933  0.002874
# FAG_10_SUNTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.433459  0.018978
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR           0.433211  0.128679
# FAG_10_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR     0.427530 -0.042480
# MAG_30_SUNTM_3_FLPOP_RATIO vs SELNG_PRER_STOR     0.419496 -0.047767
# FAG_10_SATTM_1_FLPOP_CO vs SELNG_PRER_STOR        0.410538 -0.009135
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR              0.391182 -0.122751
# FAG_10_SATTM_4_FLPOP_RATIO vs SELNG_PRER_STOR     0.344245  0.061576
# DAY_WED_FLPOP_RATIO vs SELNG_PRER_STOR            0.313674  0.097764
# FAG_10_SUNTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.310451  0.053856
# FAG_10_SATTM_5_FLPOP_RATIO vs SELNG_PRER_STOR     0.270890  0.067596
# FAG_10_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR     0.263101  0.021806
# 부동산중개업_STOR_CO vs SELNG_PRER_STOR                 0.209358  0.027064
# HGSCHL_CO vs SELNG_PRER_STOR                      0.206256 -0.003620
# GNRL_HSPTL_CO vs SELNG_PRER_STOR                  0.196325  0.022404
# PBLOFC_CO vs SELNG_PRER_STOR                      0.128074  0.057767
#
# [1277 rows x 12 columns]

# %%
index = []
for i in df.values:
    i = i[0:-2]
    if max(abs(i)) < 0.15:
        index.append(False)
    else:
        index.append(True)

# %%
df = df[index]

# %%
df = df.sort_values(['var','mean'],ascending = False)
df
# Out:
#                                                          분식집       양식집  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR            0.063474  0.273555
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR                0.142927  0.198989
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.217315  0.208538
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.212258  0.199897
# STOR_CO vs SELNG_PRER_STOR                          0.131738  0.209544
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.211227  0.202448
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR               0.224948  0.211349
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR          0.136506  0.114081
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.201460  0.196530
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.201569  0.185431
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.099498  0.133423
# INCOME_SCTN_CD vs SELNG_PRER_STOR                   0.217234  0.206285
# THEAT_CO vs SELNG_PRER_STOR                         0.149597  0.156182
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.212749  0.163285
# 분식집_STOR_CO vs SELNG_PRER_STOR                      0.123595  0.003458
# 일식집_STOR_CO vs SELNG_PRER_STOR                      0.158147  0.031669
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.200066  0.125684
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                    0.178871  0.057630
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR             0.146083  0.136487
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR          0.171834  0.117464
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.212222  0.142614
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.098461  0.073234
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.208641  0.138186
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.135183  0.131926
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                  0.061005  0.197502
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.213116  0.135373
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR                0.071446  0.201525
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.210401  0.215804
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                   0.185568  0.119340
# FAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.219598  0.212432
# ...                                                      ...       ...
# MAG_60_ABOVE_THUTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.182357 -0.178705
# MAG_60_ABOVE_WEDTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.196017 -0.181118
# FAG_30_THUTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.158717  0.077504
# FAG_10_WRC_POPLTN_CO vs SELNG_PRER_STOR             0.144885  0.134835
# MAG_50_FRITM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.140250 -0.093133
# MAG_40_FRITM_4_FLPOP_RATIO vs SELNG_PRER_STOR       0.107235  0.099107
# FAG_20_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.216769  0.181098
# FAG_30_MONTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.151686  0.071737
# 헬스클럽_STOR_CO vs SELNG_PRER_STOR                     0.119959  0.063663
# FAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.160814 -0.133419
# FAG_30_SATTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.150928  0.078488
# PC_1_HDMIL_HSHLD_CO vs SELNG_PRER_STOR             -0.130533 -0.166919
# MAG_50_MONTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.141472 -0.096983
# MAG_40_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.202448 -0.201210
# MAG_30_MONTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.160688 -0.171770
# TMZON_4_FLPOP_RATIO vs SELNG_PRER_STOR              0.149595  0.163463
# TMZON_3_FLPOP_RATIO vs SELNG_PRER_STOR              0.141091  0.147207
# MAG_50_WEDTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.138126 -0.091734
# FAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.159833 -0.144065
# FAG_30_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.121801  0.129779
# MAG_30_TUETM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.137840 -0.157891
# MAG_30_WEDTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.137672 -0.155525
# 과일채소_STOR_CO vs SELNG_PRER_STOR                    -0.119441 -0.183978
# MAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.163467 -0.141757
# DAY_SUN_FLPOP_RATIO vs SELNG_PRER_STOR             -0.171686 -0.141822
# MAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.156578 -0.157180
# 과일채소_점포수의__STOR_CO vs SELNG_PRER_STOR              -0.119219 -0.150962
# 정육점_STOR_CO vs SELNG_PRER_STOR                     -0.147209 -0.164696
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR             0.144139  0.112357
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR               -0.140389 -0.152714
#
#                                                          일식집       제과점  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR            0.159865  0.249728
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR                0.027444  0.059691
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.175348  0.089337
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.170990  0.087914
# STOR_CO vs SELNG_PRER_STOR                          0.125063  0.065783
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.165723  0.085950
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR               0.184658  0.169926
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR          0.114562  0.051031
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.162526  0.086247
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.163836  0.076477
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.075446  0.110474
# INCOME_SCTN_CD vs SELNG_PRER_STOR                   0.190517  0.168040
# THEAT_CO vs SELNG_PRER_STOR                         0.063028  0.043107
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.162179  0.120529
# 분식집_STOR_CO vs SELNG_PRER_STOR                      0.074464  0.070833
# 일식집_STOR_CO vs SELNG_PRER_STOR                      0.108468  0.107134
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.148133  0.078534
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                    0.113530  0.050139
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR             0.139085  0.078785
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR          0.141046  0.083556
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.170044  0.146365
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.021498  0.112915
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.150612  0.094866
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.122329  0.098254
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                  0.041916  0.072335
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.149047  0.090578
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR                0.030267  0.057971
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.176451  0.139913
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                   0.136099  0.072287
# FAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.180376  0.146490
# ...                                                      ...       ...
# MAG_60_ABOVE_THUTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.125063 -0.113444
# MAG_60_ABOVE_WEDTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.135978 -0.120235
# FAG_30_THUTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.101646  0.078945
# FAG_10_WRC_POPLTN_CO vs SELNG_PRER_STOR             0.171527  0.145330
# MAG_50_FRITM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.076468 -0.052773
# MAG_40_FRITM_4_FLPOP_RATIO vs SELNG_PRER_STOR       0.084653  0.076594
# FAG_20_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.159206  0.125234
# FAG_30_MONTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.096475  0.074493
# 헬스클럽_STOR_CO vs SELNG_PRER_STOR                     0.080632  0.156863
# FAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.093995 -0.076215
# FAG_30_SATTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.089156  0.065595
# PC_1_HDMIL_HSHLD_CO vs SELNG_PRER_STOR             -0.085736 -0.114861
# MAG_50_MONTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.086423 -0.059412
# MAG_40_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.147175 -0.113955
# MAG_30_MONTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.096246 -0.136445
# TMZON_4_FLPOP_RATIO vs SELNG_PRER_STOR              0.098843  0.112719
# TMZON_3_FLPOP_RATIO vs SELNG_PRER_STOR              0.101782  0.129194
# MAG_50_WEDTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.081915 -0.058006
# FAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.100355 -0.106006
# FAG_30_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.126700  0.114139
# MAG_30_TUETM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.076889 -0.126148
# MAG_30_WEDTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.077895 -0.128281
# 과일채소_STOR_CO vs SELNG_PRER_STOR                    -0.130491 -0.158832
# MAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.096017 -0.163901
# DAY_SUN_FLPOP_RATIO vs SELNG_PRER_STOR             -0.143063 -0.119811
# MAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.106590 -0.100884
# 과일채소_점포수의__STOR_CO vs SELNG_PRER_STOR              -0.110784 -0.126821
# 정육점_STOR_CO vs SELNG_PRER_STOR                     -0.150552 -0.149187
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR             0.105373  0.106502
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR               -0.118449 -0.153544
#
#                                                          중국집       치킨집  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR            0.064676  0.117714
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR                0.049721 -0.027799
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.233693  0.173461
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.241977  0.172706
# STOR_CO vs SELNG_PRER_STOR                          0.035784  0.061177
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.235574  0.171618
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR               0.318169  0.180018
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR          0.256719  0.149240
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.234072  0.166557
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.234609  0.165311
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.251638  0.125072
# INCOME_SCTN_CD vs SELNG_PRER_STOR                   0.299399  0.161231
# THEAT_CO vs SELNG_PRER_STOR                         0.093450 -0.011130
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.252087  0.147809
# 분식집_STOR_CO vs SELNG_PRER_STOR                      0.094856  0.194421
# 일식집_STOR_CO vs SELNG_PRER_STOR                      0.112150  0.137287
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.222479  0.137384
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                    0.089767  0.208274
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR             0.217596  0.090068
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR          0.213152  0.106505
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.247813  0.170774
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.201417  0.098404
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.218853  0.151152
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.277733  0.126075
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                  0.026796  0.046109
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.212399  0.160041
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR                0.031485  0.055470
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.260051  0.136129
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                   0.195888  0.126496
# FAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.279867  0.155469
# ...                                                      ...       ...
# MAG_60_ABOVE_THUTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.170537 -0.156456
# MAG_60_ABOVE_WEDTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.168690 -0.161605
# FAG_30_THUTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.155369  0.131527
# FAG_10_WRC_POPLTN_CO vs SELNG_PRER_STOR             0.158429  0.103535
# MAG_50_FRITM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.087365 -0.114025
# MAG_40_FRITM_4_FLPOP_RATIO vs SELNG_PRER_STOR       0.122205  0.063606
# FAG_20_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.158453  0.183979
# FAG_30_MONTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.152555  0.124461
# 헬스클럽_STOR_CO vs SELNG_PRER_STOR                     0.132355  0.159468
# FAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.138619 -0.122923
# FAG_30_SATTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.124130  0.117749
# PC_1_HDMIL_HSHLD_CO vs SELNG_PRER_STOR             -0.100016 -0.166469
# MAG_50_MONTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.101946 -0.111537
# MAG_40_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.165846 -0.156245
# MAG_30_MONTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.144846 -0.113837
# TMZON_4_FLPOP_RATIO vs SELNG_PRER_STOR              0.143690  0.096633
# TMZON_3_FLPOP_RATIO vs SELNG_PRER_STOR              0.171640  0.102407
# MAG_50_WEDTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.094575 -0.112992
# FAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.101742 -0.105051
# FAG_30_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.141193  0.074603
# MAG_30_TUETM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.125512 -0.088339
# MAG_30_WEDTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.123508 -0.090503
# 과일채소_STOR_CO vs SELNG_PRER_STOR                    -0.125714 -0.086107
# MAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.137905 -0.114058
# DAY_SUN_FLPOP_RATIO vs SELNG_PRER_STOR             -0.210154 -0.158781
# MAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.141350 -0.125398
# 과일채소_점포수의__STOR_CO vs SELNG_PRER_STOR              -0.096477 -0.104497
# 정육점_STOR_CO vs SELNG_PRER_STOR                     -0.125316 -0.098432
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR             0.172514  0.134552
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR               -0.111947 -0.115108
#
#                                                         커피음료    패스트푸드점  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR            0.193213  0.018622
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR                0.164287  0.098018
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.232169  0.111555
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.233897  0.112809
# STOR_CO vs SELNG_PRER_STOR                          0.213395  0.066289
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.229976  0.113719
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR               0.149115  0.139329
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR          0.142404  0.051039
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.221037  0.113524
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.209438  0.107919
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.071231  0.033782
# INCOME_SCTN_CD vs SELNG_PRER_STOR                   0.165158  0.124631
# THEAT_CO vs SELNG_PRER_STOR                         0.153978  0.037231
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.158481  0.044886
# 분식집_STOR_CO vs SELNG_PRER_STOR                      0.136757  0.018856
# 일식집_STOR_CO vs SELNG_PRER_STOR                      0.193217  0.036491
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.125492  0.038501
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                    0.178715  0.046555
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR             0.122006  0.044530
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR          0.107424  0.024694
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.159663  0.036880
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.046164  0.013317
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.141822  0.039426
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.151436  0.065403
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                  0.150407  0.046886
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.137020  0.041781
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR                0.142697  0.053798
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.220722  0.126673
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                   0.123744  0.023811
# FAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.228788  0.131275
# ...                                                      ...       ...
# MAG_60_ABOVE_THUTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.163648 -0.114820
# MAG_60_ABOVE_WEDTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.171801 -0.125903
# FAG_30_THUTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.155812  0.093516
# FAG_10_WRC_POPLTN_CO vs SELNG_PRER_STOR             0.174841  0.173649
# MAG_50_FRITM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.140402 -0.110171
# MAG_40_FRITM_4_FLPOP_RATIO vs SELNG_PRER_STOR       0.089530  0.048888
# FAG_20_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.178626  0.126418
# FAG_30_MONTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.147678  0.093758
# 헬스클럽_STOR_CO vs SELNG_PRER_STOR                     0.105908  0.136212
# FAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.108970 -0.065543
# FAG_30_SATTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.147978  0.084137
# PC_1_HDMIL_HSHLD_CO vs SELNG_PRER_STOR             -0.170801 -0.126545
# MAG_50_MONTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.133693 -0.104142
# MAG_40_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.188932 -0.145085
# MAG_30_MONTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.189115 -0.133037
# TMZON_4_FLPOP_RATIO vs SELNG_PRER_STOR              0.157853  0.119176
# TMZON_3_FLPOP_RATIO vs SELNG_PRER_STOR              0.113354  0.105334
# MAG_50_WEDTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.130583 -0.106485
# FAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.167519 -0.124915
# FAG_30_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.094324  0.081884
# MAG_30_TUETM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.159131 -0.119184
# MAG_30_WEDTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.160682 -0.120651
# 과일채소_STOR_CO vs SELNG_PRER_STOR                    -0.106802 -0.128376
# MAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.145350 -0.142146
# DAY_SUN_FLPOP_RATIO vs SELNG_PRER_STOR             -0.164651 -0.158133
# MAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.116123 -0.089907
# 과일채소_점포수의__STOR_CO vs SELNG_PRER_STOR              -0.093537 -0.080860
# 정육점_STOR_CO vs SELNG_PRER_STOR                     -0.114888 -0.160029
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR             0.130490  0.115059
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR               -0.116725 -0.120021
#
#                                                        한식음식점    호프간이주점  \
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR            0.156633  0.031832
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR               -0.005291 -0.002551
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.304147  0.272852
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.299510  0.272211
# STOR_CO vs SELNG_PRER_STOR                          0.175318  0.078117
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.294422  0.263072
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR               0.303528  0.279976
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR          0.176635  0.201792
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.286607  0.260214
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.280220  0.249039
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.150025  0.185698
# INCOME_SCTN_CD vs SELNG_PRER_STOR                   0.301022  0.273737
# THEAT_CO vs SELNG_PRER_STOR                         0.148195  0.142306
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.245514  0.189444
# 분식집_STOR_CO vs SELNG_PRER_STOR                      0.063888  0.163505
# 일식집_STOR_CO vs SELNG_PRER_STOR                      0.199599  0.186030
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.221576  0.172502
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                    0.144064  0.161099
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR             0.209313  0.208327
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR          0.210357  0.149223
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               0.217911  0.197161
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.105191  0.151357
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        0.217581  0.181131
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        0.117072  0.177124
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                  0.083470  0.023727
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             0.211620  0.184944
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR                0.101104  0.039820
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.282253  0.251133
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                   0.198007  0.154792
# FAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       0.283477  0.256196
# ...                                                      ...       ...
# MAG_60_ABOVE_THUTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.171734 -0.210696
# MAG_60_ABOVE_WEDTM_6_FLPOP_RATIO vs SELNG_PRER_... -0.179004 -0.221349
# FAG_30_THUTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.125225  0.136850
# FAG_10_WRC_POPLTN_CO vs SELNG_PRER_STOR             0.216237  0.125580
# MAG_50_FRITM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.116598 -0.151008
# MAG_40_FRITM_4_FLPOP_RATIO vs SELNG_PRER_STOR       0.158472  0.085226
# FAG_20_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.187659  0.208351
# FAG_30_MONTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.120794  0.129557
# 헬스클럽_STOR_CO vs SELNG_PRER_STOR                     0.131669  0.125311
# FAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.111055 -0.144321
# FAG_30_SATTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.106012  0.133617
# PC_1_HDMIL_HSHLD_CO vs SELNG_PRER_STOR             -0.142655 -0.150086
# MAG_50_MONTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.114029 -0.161619
# MAG_40_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.182413 -0.184562
# MAG_30_MONTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.166378 -0.131126
# TMZON_4_FLPOP_RATIO vs SELNG_PRER_STOR              0.167781  0.105124
# TMZON_3_FLPOP_RATIO vs SELNG_PRER_STOR              0.170908  0.104318
# MAG_50_WEDTM_2_FLPOP_RATIO vs SELNG_PRER_STOR      -0.109061 -0.150107
# FAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.143009 -0.090309
# FAG_30_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.164038  0.115887
# MAG_30_TUETM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.136730 -0.104990
# MAG_30_WEDTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.138753 -0.101862
# 과일채소_STOR_CO vs SELNG_PRER_STOR                    -0.126637 -0.132793
# MAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR      -0.150157 -0.089057
# DAY_SUN_FLPOP_RATIO vs SELNG_PRER_STOR             -0.189668 -0.157691
# MAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR      -0.106596 -0.145954
# 과일채소_점포수의__STOR_CO vs SELNG_PRER_STOR              -0.123085 -0.079478
# 정육점_STOR_CO vs SELNG_PRER_STOR                     -0.120849 -0.127998
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR             0.142337  0.123467
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR               -0.095643 -0.102971
#
#                                                          var      mean
# variable_name
# SIMILR_INDUTY_STOR_CO vs SELNG_PRER_STOR            7.926666  0.132931
# AVRG_BSN_MONTH_CO vs SELNG_PRER_STOR                6.050477  0.070544
# MAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       4.449305  0.201842
# MAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       4.436489  0.200417
# STOR_CO vs SELNG_PRER_STOR                          4.216917  0.116221
# MAG_30_WEDTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       4.172551  0.197373
# MT_AVRG_INCOME_AMT vs SELNG_PRER_STOR               4.116250  0.216102
# MAG_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR          4.003544  0.139401
# MAG_30_TUETM_5_FLPOP_RATIO vs SELNG_PRER_STOR       3.908612  0.192877
# MAG_30_MONTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       3.888711  0.187385
# PC_4_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              3.880959  0.123629
# INCOME_SCTN_CD vs SELNG_PRER_STOR                   3.801984  0.210725
# THEAT_CO vs SELNG_PRER_STOR                         3.724557  0.097594
# LSR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               3.719747  0.169696
# 분식집_STOR_CO vs SELNG_PRER_STOR                      3.698637  0.094463
# 일식집_STOR_CO vs SELNG_PRER_STOR                      3.606003  0.127019
# LVSPL_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             3.577261  0.147035
# 한식음식점_STOR_CO vs SELNG_PRER_STOR                    3.556940  0.122864
# AGRDE_30_FLPOP_RATIO vs SELNG_PRER_STOR             3.468560  0.139228
# TRNSPORT_EXPNDTR_TOTAMT vs SELNG_PRER_STOR          3.334945  0.132526
# EDC_EXPNDTR_TOTAMT vs SELNG_PRER_STOR               3.334154  0.170145
# PC_3_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              3.311518  0.092196
# CLTHS_FTWR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR        3.223523  0.154227
# AGRDE_30_WRC_POPLTN_RATIO vs SELNG_PRER_STOR        3.211831  0.140253
# YEAR_1_BEING_RT vs SELNG_PRER_STOR                  3.182210  0.075015
# PLESR_EXPNDTR_TOTAMT vs SELNG_PRER_STOR             3.165863  0.153592
# YEAR_1_2_BEING_RT vs SELNG_PRER_STOR                3.045791  0.078559
# FAG_30_FRITM_5_FLPOP_RATIO vs SELNG_PRER_STOR       3.039637  0.201953
# EXPNDTR_TOTAMT vs SELNG_PRER_STOR                   3.038645  0.133603
# FAG_30_THUTM_5_FLPOP_RATIO vs SELNG_PRER_STOR       2.993779  0.209397
# ...                                                      ...       ...
# MAG_60_ABOVE_THUTM_6_FLPOP_RATIO vs SELNG_PRER_...  1.011994 -0.158746
# MAG_60_ABOVE_WEDTM_6_FLPOP_RATIO vs SELNG_PRER_...  1.002847 -0.166170
# FAG_30_THUTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.998161  0.121511
# FAG_10_WRC_POPLTN_CO vs SELNG_PRER_STOR             0.988087  0.154885
# MAG_50_FRITM_2_FLPOP_RATIO vs SELNG_PRER_STOR       0.971702 -0.108219
# MAG_40_FRITM_4_FLPOP_RATIO vs SELNG_PRER_STOR       0.955286  0.093551
# FAG_20_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.938854  0.172580
# FAG_30_MONTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.938731  0.116319
# 헬스클럽_STOR_CO vs SELNG_PRER_STOR                     0.933814  0.121204
# FAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR       0.928719 -0.115587
# FAG_30_SATTM_4_FLPOP_CO vs SELNG_PRER_STOR          0.890938  0.109779
# PC_1_HDMIL_HSHLD_CO vs SELNG_PRER_STOR              0.858070 -0.135462
# MAG_50_MONTM_2_FLPOP_RATIO vs SELNG_PRER_STOR       0.845098 -0.111126
# MAG_40_SATTM_1_FLPOP_RATIO vs SELNG_PRER_STOR       0.802885 -0.168787
# MAG_30_MONTM_1_FLPOP_RATIO vs SELNG_PRER_STOR       0.790948 -0.144349
# TMZON_4_FLPOP_RATIO vs SELNG_PRER_STOR              0.776763  0.131488
# TMZON_3_FLPOP_RATIO vs SELNG_PRER_STOR              0.768174  0.128724
# MAG_50_WEDTM_2_FLPOP_RATIO vs SELNG_PRER_STOR       0.759927 -0.107358
# FAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR       0.757140 -0.124280
# FAG_30_SATTM_3_FLPOP_RATIO vs SELNG_PRER_STOR       0.736606  0.116435
# MAG_30_TUETM_1_FLPOP_RATIO vs SELNG_PRER_STOR       0.734843 -0.123265
# MAG_30_WEDTM_1_FLPOP_RATIO vs SELNG_PRER_STOR       0.723268 -0.123533
# 과일채소_STOR_CO vs SELNG_PRER_STOR                     0.706831 -0.129917
# MAG_30_SUNTM_1_FLPOP_RATIO vs SELNG_PRER_STOR       0.683653 -0.134381
# DAY_SUN_FLPOP_RATIO vs SELNG_PRER_STOR              0.641410 -0.161546
# MAG_40_SATTM_6_FLPOP_RATIO vs SELNG_PRER_STOR       0.589738 -0.124656
# 과일채소_점포수의__STOR_CO vs SELNG_PRER_STOR               0.495798 -0.108572
# 정육점_STOR_CO vs SELNG_PRER_STOR                      0.464102 -0.135916
# DAY_THUR_FLPOP_RATIO vs SELNG_PRER_STOR             0.433211  0.128679
# 정육점_점포수의__STOR_CO vs SELNG_PRER_STOR                0.391182 -0.122751
#
# [477 rows x 12 columns]

# %%
variable_name = df.index[0] 
v1 = df.values[0][:-2].tolist()

# %%
# Out:
# [0.0634735234446532,
#  0.27355465320459743,
#  0.15986480938610315,
#  0.2497283776435087,
#  0.0646764274637094,
#  0.11771397954752542,
#  0.1932131578238397,
#  0.018621602701786782,
#  0.1566326955802211,
#  0.0318320804712079]

# %%
attr = list(df)[:-2]

bar = Bar(variable_name)

bar.add("상관계수", attr, v1,)


bar.height = 600
bar.width = 1100
bar
# ?bar

# %%
# 한 파일내 모든 pickle를 불러온다.
import os
from tqdm import tqdm 
import pandas as pd
os.chdir(r"C:\Users\igaworks\DATA\2차 광고제안서\visual")

names = os.listdir(r"C:\Users\igaworks\DATA\2차 광고제안서\visual\cluster") 

def csv(name):
    file = pd.read_csv('cluster/' + name, engine = "c")
    return file  

dfs = []
for i in tqdm(names):
    print
    dfs.append(csv(i))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 135.41it/s]

# %%
new_names = []
for name in names:
    tmp = name.replace('.csv','')
    new_names.append(tmp)

# %%
Vs = []
for df in dfs:
        if len(df) == 24:
            v = df[df.gender == 'F'].ratio.values + df[df.gender == 'M'].ratio.values
            v = [round(x, 1) for x in v]
            Vs.append(v)
        else:
            pass

# %%
attr = ['20대 미만','20대', '30대', '40대', '50대', '60대 이상']
line = Line("서비스별 사용자 구성", '2019년 1월 ~ 2019년 7월 평균지수 ')
line.use_theme("shine")
v_r = [2.78,38.1,32.5,19.11,6.14,1.38]
v_sw = [1.77,14.33,32.76,34.31,13.87,2.96]
v_y = [1.06,14.1,38.5,33.52,11.21,1.6]
v_sm = [0.84,19.93,39.37,30.01,8.65,1.19]

line.add('스피킹맥스', attr,v_sm,line_width = 6,line_opacity = 0.7)
line.add('야나두', attr,v_y,line_width = 6,line_opacity = 0.7)
line.add('시원스쿨', attr,v_sw,line_width = 6,line_opacity = 0.7)
line.add('리얼클래스', attr,v_r,line_width = 6,line_opacity = 0.7)
line.height = 600
line.width = 1200
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'shine': '/nbextensions/echarts-themes-js/shine'
#         }
#     });
# </script>
#     <div id="f6fd44caccd74f3dac18cf5bda668d10" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'shine'], function(echarts) {
#
# var myChart_f6fd44caccd74f3dac18cf5bda668d10 = echarts.init(document.getElementById('f6fd44caccd74f3dac18cf5bda668d10'), 'shine', {renderer: 'canvas'});
#
# var option_f6fd44caccd74f3dac18cf5bda668d10 = {
#     "title": [
#         {
#             "text": "\uc11c\ube44\uc2a4\ubcc4 \uc0ac\uc6a9\uc790 \uad6c\uc131",
#             "subtext": "2019\ub144 1\uc6d4 ~ 2019\ub144 7\uc6d4 \ud3c9\uade0\uc9c0\uc218 ",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5962442,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\uc2a4\ud53c\ud0b9\ub9e5\uc2a4",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "20\ub300 \ubbf8\ub9cc",
#                     0.84
#                 ],
#                 [
#                     "20\ub300",
#                     19.93
#                 ],
#                 [
#                     "30\ub300",
#                     39.37
#                 ],
#                 [
#                     "40\ub300",
#                     30.01
#                 ],
#                 [
#                     "50\ub300",
#                     8.65
#                 ],
#                 [
#                     "60\ub300 \uc774\uc0c1",
#                     1.19
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 6,
#                     "opacity": 0.7,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5962442
#         },
#         {
#             "type": "line",
#             "name": "\uc57c\ub098\ub450",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "20\ub300 \ubbf8\ub9cc",
#                     1.06
#                 ],
#                 [
#                     "20\ub300",
#                     14.1
#                 ],
#                 [
#                     "30\ub300",
#                     38.5
#                 ],
#                 [
#                     "40\ub300",
#                     33.52
#                 ],
#                 [
#                     "50\ub300",
#                     11.21
#                 ],
#                 [
#                     "60\ub300 \uc774\uc0c1",
#                     1.6
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 6,
#                     "opacity": 0.7,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5962442
#         },
#         {
#             "type": "line",
#             "name": "\uc2dc\uc6d0\uc2a4\ucfe8",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "20\ub300 \ubbf8\ub9cc",
#                     1.77
#                 ],
#                 [
#                     "20\ub300",
#                     14.33
#                 ],
#                 [
#                     "30\ub300",
#                     32.76
#                 ],
#                 [
#                     "40\ub300",
#                     34.31
#                 ],
#                 [
#                     "50\ub300",
#                     13.87
#                 ],
#                 [
#                     "60\ub300 \uc774\uc0c1",
#                     2.96
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 6,
#                     "opacity": 0.7,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5962442
#         },
#         {
#             "type": "line",
#             "name": "\ub9ac\uc5bc\ud074\ub798\uc2a4",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "20\ub300 \ubbf8\ub9cc",
#                     2.78
#                 ],
#                 [
#                     "20\ub300",
#                     38.1
#                 ],
#                 [
#                     "30\ub300",
#                     32.5
#                 ],
#                 [
#                     "40\ub300",
#                     19.11
#                 ],
#                 [
#                     "50\ub300",
#                     6.14
#                 ],
#                 [
#                     "60\ub300 \uc774\uc0c1",
#                     1.38
#                 ]
#             ],
#             "label": {

# %%
# 한 파일내 모든 csv를 불러온다.
import os
from tqdm import tqdm 
import pandas as pd
os.chdir(r"C:\Users\igaworks\DATA\2차 광고제안서\visual")

names = os.listdir(r"C:\Users\igaworks\DATA\2차 광고제안서\visual\package") 

def csv(name):
    file = pd.read_csv('package/' + name, engine = "python")
    return file  

dfs = []
for i in tqdm(names):
    print
    dfs.append(csv(i))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 127.38it/s]

# %%
new_names = []
for name in names:
    tmp = name.replace('.csv','')
    new_names.append(tmp)

# %%
Vs = []
for df in dfs:
        if len(df) == 24:
            v = df[df.gender == 'F'].ratio.values + df[df.gender == 'M'].ratio.values
            v = [round(x, 1) for x in v]
            Vs.append(v)
        else:
            pass

# %%
# line 그래프를 그린다.
from pyecharts import Line
attr = ['0 ~ 12', '13~ 18','19 ~ 24', '25 ~ 29', '30 ~ 34','35 ~ 39', '40 ~ 44', '45 ~ 49', '50 ~ 54','55 ~ 59', '60 ~ 64','65~']
line = Line("", '')
line.use_theme("walden")
for i in range(len(new_names)):
    try:
        line.add(new_names[i], attr, Vs[i])
    except:
        pass
line.height = 800
line.width = 1000
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'walden': '/nbextensions/echarts-themes-js/walden'
#         }
#     });
# </script>
#     <div id="fc0f86cf40544b8eaa1bf9ec482faa65" style="width:1000px;height:800px;"></div>
#
#
# <script>
#     require(['echarts', 'walden'], function(echarts) {
#
# var myChart_fc0f86cf40544b8eaa1bf9ec482faa65 = echarts.init(document.getElementById('fc0f86cf40544b8eaa1bf9ec482faa65'), 'walden', {renderer: 'canvas'});
#
# var option_fc0f86cf40544b8eaa1bf9ec482faa65 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2646191,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Cake(\ucf00\uc774\ud06c)",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "0 ~ 12",
#                     0.2
#                 ],
#                 [
#                     "13~ 18",
#                     5.8
#                 ],
#                 [
#                     "19 ~ 24",
#                     11.5
#                 ],
#                 [
#                     "25 ~ 29",
#                     9.9
#                 ],
#                 [
#                     "30 ~ 34",
#                     7.7
#                 ],
#                 [
#                     "35 ~ 39",
#                     14.8
#                 ],
#                 [
#                     "40 ~ 44",
#                     13.8
#                 ],
#                 [
#                     "45 ~ 49",
#                     15.7
#                 ],
#                 [
#                     "50 ~ 54",
#                     7.4
#                 ],
#                 [
#                     "55 ~ 59",
#                     8.1
#                 ],
#                 [
#                     "60 ~ 64",
#                     3.8
#                 ],
#                 [
#                     "65~",
#                     1.4
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2646191
#         },
#         {
#             "type": "line",
#             "name": "EBS English EBS(\ud55c\uad6d\uad50\uc721\ubc29\uc1a1\uacf5\uc0ac)",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "0 ~ 12",
#                     0.3
#                 ],
#                 [
#                     "13~ 18",
#                     1.5
#                 ],
#                 [
#                     "19 ~ 24",
#                     2.5
#                 ],
#                 [
#                     "25 ~ 29",
#                     3.5
#                 ],
#                 [
#                     "30 ~ 34",
#                     6.0
#                 ],
#                 [
#                     "35 ~ 39",
#                     18.8
#                 ],
#                 [
#                     "40 ~ 44",
#                     22.5
#                 ],
#                 [
#                     "45 ~ 49",
#                     23.4
#                 ],
#                 [
#                     "50 ~ 54",
#                     7.9
#                 ],
#                 [
#                     "55 ~ 59",
#                     8.8
#                 ],
#                 [
#                     "60 ~ 64",
#                     3.7
#                 ],
#                 [
#                     "65~",
#                     1.2
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2646191
#         },
#         {
#             "type": "line",
#             "name": "ETS TOEIC Books by YBM YBM NET",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "0 ~ 12",
#                     0.0
#                 ],
#                 [
#                     "13~ 18",
#                     3.0
#                 ],
#                 [
#                     "19 ~ 24",
#                     41.5
#                 ],
#                 [
#                     "25 ~ 29",
#                     27.7
#                 ],
#                 [
#                     "30 ~ 34",
#                     7.9
#                 ],
#                 [
#                     "35 ~ 39",
#                     7.6
#                 ],
#                 [
#                     "40 ~ 44",
#                     4.9
#                 ],
#                 [
#                     "45 ~ 49",
#                     4.3
#                 ],
#                 [
#                     "50 ~ 54",
#                     1.2
#                 ],
#                 [
#                     "55 ~ 59",
#                     1.2
#                 ],
#                 [
#                     "60 ~ 64",
#                     0.3
#                 ],
#                 [
#                     "65~",
#                     0.2
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }

# %%
attr = ['책/강의','생활영어','산타토익','체험형회화']
v_20 = [10.62,4.39,13.58,71.40]
v_30 = [17.17,14.86,1.84,66.14]

# %%
from pyecharts import Pie

pie = Pie("20대의 설치 앱의 상대빈도", title_pos='center', width=900)

pie.add("20대", attr, v_20, center=[50, 50], is_random=False, radius=[30, 75],
        is_legend_show=True, is_label_show=False,legend_pos='left',legend_orient='vertical',legend_top="center")

pie.height = 400
pie.width = 500
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="dfe35a061ee14b4986b04865768124ac" style="width:500px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_dfe35a061ee14b4986b04865768124ac = echarts.init(document.getElementById('dfe35a061ee14b4986b04865768124ac'), 'light', {renderer: 'canvas'});
#
# var option_dfe35a061ee14b4986b04865768124ac = {
#     "title": [
#         {
#             "text": "20\ub300\uc758 \uc124\uce58 \uc571\uc758 \uc0c1\ub300\ube48\ub3c4",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3913249,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "20\ub300",
#             "data": [
#                 {
#                     "name": "\ucc45/\uac15\uc758",
#                     "value": 10.62
#                 },
#                 {
#                     "name": "\uc0dd\ud65c\uc601\uc5b4",
#                     "value": 4.39
#                 },
#                 {
#                     "name": "\uc0b0\ud0c0\ud1a0\uc775",
#                     "value": 13.58
#                 },
#                 {
#                     "name": "\uccb4\ud5d8\ud615\ud68c\ud654",
#                     "value": 71.4
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 3913249
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\ucc45/\uac15\uc758",
#                 "\uc0dd\ud65c\uc601\uc5b4",
#                 "\uc0b0\ud0c0\ud1a0\uc775",
#                 "\uccb4\ud5d8\ud615\ud68c\ud654"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "center",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_dfe35a061ee14b4986b04865768124ac.setOption(option_dfe35a061ee14b4986b04865768124ac);
#
#     });
# </script>

# %%
pie = Pie("30의 설치 앱의 상대빈도", title_pos='center', width=900)

pie.add("30대", attr, v_30, center=[50, 50], is_random=False, radius=[30, 75],
        is_legend_show=True, is_label_show=False,legend_pos='left',legend_orient='vertical',legend_top="center")

pie.height = 400
pie.width = 500
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0bb5afc33a3a419b816249a93a47d74e" style="width:500px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0bb5afc33a3a419b816249a93a47d74e = echarts.init(document.getElementById('0bb5afc33a3a419b816249a93a47d74e'), 'light', {renderer: 'canvas'});
#
# var option_0bb5afc33a3a419b816249a93a47d74e = {
#     "title": [
#         {
#             "text": "30\uc758 \uc124\uce58 \uc571\uc758 \uc0c1\ub300\ube48\ub3c4",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2198854,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "30\ub300",
#             "data": [
#                 {
#                     "name": "\ucc45/\uac15\uc758",
#                     "value": 17.17
#                 },
#                 {
#                     "name": "\uc0dd\ud65c\uc601\uc5b4",
#                     "value": 14.86
#                 },
#                 {
#                     "name": "\uc0b0\ud0c0\ud1a0\uc775",
#                     "value": 1.84
#                 },
#                 {
#                     "name": "\uccb4\ud5d8\ud615\ud68c\ud654",
#                     "value": 66.14
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2198854
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\ucc45/\uac15\uc758",
#                 "\uc0dd\ud65c\uc601\uc5b4",
#                 "\uc0b0\ud0c0\ud1a0\uc775",
#                 "\uccb4\ud5d8\ud615\ud68c\ud654"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "center",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0bb5afc33a3a419b816249a93a47d74e.setOption(option_0bb5afc33a3a419b816249a93a47d74e);
#
#     });
# </script>

# %%
attr = ['2019-01-07',
 '2019-01-14',
 '2019-01-21',
 '2019-01-28',
 '2019-02-04',
 '2019-02-11',
 '2019-02-18',
 '2019-02-25',
 '2019-03-04',
 '2019-03-11',
 '2019-03-18',
 '2019-03-25',
 '2019-04-01',
 '2019-04-08',
 '2019-04-15',
 '2019-04-22',
 '2019-04-29',
 '2019-05-06',
 '2019-05-13',
 '2019-05-20',
 '2019-05-27',
 '2019-06-03',
 '2019-06-10',
 '2019-06-17',
 '2019-06-24',
 '2019-07-01',
 '2019-07-08',
 '2019-07-15',
 '2019-07-22',
 '2019-07-29',
 '2019-08-05',
 '2019-08-12']

line = Line("네이버 데이터랩 검색량 데이터", '2019년 1월 ~ 2019년 8월 (단위: 주간')
line.use_theme("shine")
v_r = [6.9472,
5.15591,
4.89392,
4.57301,
4.8286,
4.51621,
4.16619,
4.24003,
5.02598,
4.82434,
4.31032,
4.20808,
4.20666,
4.07531,
4.06111,
3.35752,
3.26877,
3.18996,
3.3277,
3.01388,
3.37242,
3.2567,
4.19601,
4.16193,
3.726,
4.2201,
4.14631,
3.9539,
4.1243,
4.0604,
4.14702,
3.97449]
v_sw = [58.25712,
52.15338,
44.71912,
39.85573,
37.41764,
40.62748,
40.47909,
34.28447,
37.06122,
33.18612,
30.68272,
28.10192,
25.87967,
24.82676,
21.67229,
20.97367,
19.33502,
18.86856,
19.62967,
18.62291,
18.80253,
17.61757,
18.82312,
19.8597,
22.24241,
22.08693,
22.5257,
22.5541,
24.23818,
22.91974,
21.89736,
20.21185]


v_y = [100.0,
76.94748,
69.87461,
72.39293,
82.45981,
77.80515,
65.85184,
60.10379,
59.63307,
49.4384,
46.97049,
41.73293,
38.62319,
37.03424,
33.5965,
31.99051,
29.59786,
30.52581,
29.87901,
29.65466,
28.08204,
26.55841,
29.24358,
28.97662,
29.12146,
31.25496,
29.69016,
29.29399,
28.38662,
27.41891,
27.85982,
26.91341]

v_sm = [25.2066,
21.44936,
20.55194,
17.19726,
17.87174,
17.86322,
15.69422,
15.30231,
15.56997,
13.48474,
12.41764,
11.62316,
10.5589,
9.905,
8.90463,
8.80807,
7.55424,
10.14852,
10.50636,
10.02357,
10.00937,
9.9547,
10.5908,
9.50528,
9.85104,
9.61674,
10.02215,
9.26743,
9.01113,
8.38847,
8.9167,
8.98344]

line.add('스피킹맥스', attr,v_sm,line_width = 6,line_opacity = 0.7)
line.add('야나두', attr,v_y,line_width = 6,line_opacity = 0.7)
line.add('시원스쿨', attr,v_sw,line_width = 6,line_opacity = 0.7)
line.add('리얼클래스', attr,v_r,line_width = 6,line_opacity = 0.7)
line.height = 600
line.width = 1200
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'shine': '/nbextensions/echarts-themes-js/shine'
#         }
#     });
# </script>
#     <div id="33ebab69a1a14943a20e28effa8d2f80" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'shine'], function(echarts) {
#
# var myChart_33ebab69a1a14943a20e28effa8d2f80 = echarts.init(document.getElementById('33ebab69a1a14943a20e28effa8d2f80'), 'shine', {renderer: 'canvas'});
#
# var option_33ebab69a1a14943a20e28effa8d2f80 = {
#     "title": [
#         {
#             "text": "\ub124\uc774\ubc84 \ub370\uc774\ud130\ub7a9 \uac80\uc0c9\ub7c9 \ub370\uc774\ud130",
#             "subtext": "2019\ub144 1\uc6d4 ~ 2019\ub144 8\uc6d4 (\ub2e8\uc704: \uc8fc\uac04",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 8860268,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\uc2a4\ud53c\ud0b9\ub9e5\uc2a4",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2019-01-07",
#                     25.2066
#                 ],
#                 [
#                     "2019-01-14",
#                     21.44936
#                 ],
#                 [
#                     "2019-01-21",
#                     20.55194
#                 ],
#                 [
#                     "2019-01-28",
#                     17.19726
#                 ],
#                 [
#                     "2019-02-04",
#                     17.87174
#                 ],
#                 [
#                     "2019-02-11",
#                     17.86322
#                 ],
#                 [
#                     "2019-02-18",
#                     15.69422
#                 ],
#                 [
#                     "2019-02-25",
#                     15.30231
#                 ],
#                 [
#                     "2019-03-04",
#                     15.56997
#                 ],
#                 [
#                     "2019-03-11",
#                     13.48474
#                 ],
#                 [
#                     "2019-03-18",
#                     12.41764
#                 ],
#                 [
#                     "2019-03-25",
#                     11.62316
#                 ],
#                 [
#                     "2019-04-01",
#                     10.5589
#                 ],
#                 [
#                     "2019-04-08",
#                     9.905
#                 ],
#                 [
#                     "2019-04-15",
#                     8.90463
#                 ],
#                 [
#                     "2019-04-22",
#                     8.80807
#                 ],
#                 [
#                     "2019-04-29",
#                     7.55424
#                 ],
#                 [
#                     "2019-05-06",
#                     10.14852
#                 ],
#                 [
#                     "2019-05-13",
#                     10.50636
#                 ],
#                 [
#                     "2019-05-20",
#                     10.02357
#                 ],
#                 [
#                     "2019-05-27",
#                     10.00937
#                 ],
#                 [
#                     "2019-06-03",
#                     9.9547
#                 ],
#                 [
#                     "2019-06-10",
#                     10.5908
#                 ],
#                 [
#                     "2019-06-17",
#                     9.50528
#                 ],
#                 [
#                     "2019-06-24",
#                     9.85104
#                 ],
#                 [
#                     "2019-07-01",
#                     9.61674
#                 ],
#                 [
#                     "2019-07-08",
#                     10.02215
#                 ],
#                 [
#                     "2019-07-15",
#                     9.26743
#                 ],
#                 [
#                     "2019-07-22",
#                     9.01113
#                 ],
#                 [
#                     "2019-07-29",
#                     8.38847
#                 ],
#                 [
#                     "2019-08-05",
#                     8.9167
#                 ],
#                 [
#                     "2019-08-12",
#                     8.98344
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 6,
#                     "opacity": 0.7,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8860268
#         },
#         {
#             "type": "line",
#             "name": "\uc57c\ub098\ub450",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2019-01-07",
#                     100.0
#                 ],
#                 [
#                     "2019-01-14",
#                     76.94748
#                 ],
#                 [
#                     "2019-01-21",
#                     69.87461
#                 ],
#                 [
#                     "2019-01-28",
#                     72.39293
#                 ],
#                 [
#                     "2019-02-04",
#                     82.45981
#                 ],
#                 [
#                     "2019-02-11",
#                     77.80515
#                 ],
#                 [
#                     "2019-02-18",
#                     65.85184
#                 ],
#                 [
#                     "2019-02-25",
#                     60.10379
#                 ],
#                 [
#                     "2019-03-04",
#                     59.63307
#                 ],
#                 [
#                     "2019-03-11",
#                     49.4384
#                 ],
#                 [
#                     "2019-03-18",
#                     46.97049
#                 ],
#                 [
#                     "2019-03-25",
#                     41.73293
#                 ],
#                 [
#                     "2019-04-01",
#                     38.62319
#                 ],
#                 [
#                     "2019-04-08",
#                     37.03424
#                 ],
#                 [
#                     "2019-04-15",
#                     33.5965
#                 ],
#                 [
#                     "2019-04-22",
#                     31.99051
#                 ],

# %%
attr = ['2019-01-06',
 '2019-01-13',
 '2019-01-20',
 '2019-01-27',
 '2019-02-03',
 '2019-02-10',
 '2019-02-17',
 '2019-02-24',
 '2019-03-03',
 '2019-03-10',
 '2019-03-17',
 '2019-03-24',
 '2019-03-31',
 '2019-04-07',
 '2019-04-14',
 '2019-04-21',
 '2019-04-28',
 '2019-05-05',
 '2019-05-12',
 '2019-05-19',
 '2019-05-26',
 '2019-06-02',
 '2019-06-09',
 '2019-06-16',
 '2019-06-23',
 '2019-06-30',
 '2019-07-07',
 '2019-07-14',
 '2019-07-21',
 '2019-07-28',
 '2019-08-04',
 '2019-08-11']

line = Line("구글 트렌드 검색량 데이터", '2019년 1월 ~ 2019년 8월 (단위: 주간')
line.use_theme("shine")
v_r = [9,
14,
14,
11,
11,
12,
9,
14,
11,
17,
10,
10,
15,
15,
10,
5,
12,
7,
9,
4,
7,
8,
9,
15,
13,
15,
10,
8,
10,
19,
11,
12]

v_sw = [97,
83,
67,
77,
79,
63,
68,
66,
92,
53,
51,
55,
58,
51,
45,
36,
52,
28,
46,
40,
38,
32,
44,
42,
48,
51,
52,
52,
36,
49,
51,
49]


v_y = [100,
93,
66,
76,
83,
79,
72,
62,
70,
52,
69,
58,
41,
48,
42,
48,
36,
39,
50,
49,
40,
49,
41,
38,
40,
43,
46,
52,
35,
42,
43,
49]

v_sm = [13,
7,
14,
11,
12,
10,
14,
9,
12,
9,
15,
8,
12,
6,
4,
8,
7,
5,
15,
12,
8,
8,
9,
9,
8,
9,
12,
11,
8,
5,
8,
8]

line.add('스피킹맥스', attr,v_sm,line_width = 6,line_opacity = 0.7)
line.add('야나두', attr,v_y,line_width = 6,line_opacity = 0.7)
line.add('시원스쿨', attr,v_sw,line_width = 6,line_opacity = 0.7)
line.add('리얼클래스', attr,v_r,line_width = 6,line_opacity = 0.7)
line.height = 600
line.width = 1200
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'shine': '/nbextensions/echarts-themes-js/shine'
#         }
#     });
# </script>
#     <div id="6ecf13a7ae024ec2afc26738d6f76b0b" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'shine'], function(echarts) {
#
# var myChart_6ecf13a7ae024ec2afc26738d6f76b0b = echarts.init(document.getElementById('6ecf13a7ae024ec2afc26738d6f76b0b'), 'shine', {renderer: 'canvas'});
#
# var option_6ecf13a7ae024ec2afc26738d6f76b0b = {
#     "title": [
#         {
#             "text": "\uad6c\uae00 \ud2b8\ub80c\ub4dc \uac80\uc0c9\ub7c9 \ub370\uc774\ud130",
#             "subtext": "2019\ub144 1\uc6d4 ~ 2019\ub144 8\uc6d4 (\ub2e8\uc704: \uc8fc\uac04",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1932331,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\uc2a4\ud53c\ud0b9\ub9e5\uc2a4",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2019-01-06",
#                     13
#                 ],
#                 [
#                     "2019-01-13",
#                     7
#                 ],
#                 [
#                     "2019-01-20",
#                     14
#                 ],
#                 [
#                     "2019-01-27",
#                     11
#                 ],
#                 [
#                     "2019-02-03",
#                     12
#                 ],
#                 [
#                     "2019-02-10",
#                     10
#                 ],
#                 [
#                     "2019-02-17",
#                     14
#                 ],
#                 [
#                     "2019-02-24",
#                     9
#                 ],
#                 [
#                     "2019-03-03",
#                     12
#                 ],
#                 [
#                     "2019-03-10",
#                     9
#                 ],
#                 [
#                     "2019-03-17",
#                     15
#                 ],
#                 [
#                     "2019-03-24",
#                     8
#                 ],
#                 [
#                     "2019-03-31",
#                     12
#                 ],
#                 [
#                     "2019-04-07",
#                     6
#                 ],
#                 [
#                     "2019-04-14",
#                     4
#                 ],
#                 [
#                     "2019-04-21",
#                     8
#                 ],
#                 [
#                     "2019-04-28",
#                     7
#                 ],
#                 [
#                     "2019-05-05",
#                     5
#                 ],
#                 [
#                     "2019-05-12",
#                     15
#                 ],
#                 [
#                     "2019-05-19",
#                     12
#                 ],
#                 [
#                     "2019-05-26",
#                     8
#                 ],
#                 [
#                     "2019-06-02",
#                     8
#                 ],
#                 [
#                     "2019-06-09",
#                     9
#                 ],
#                 [
#                     "2019-06-16",
#                     9
#                 ],
#                 [
#                     "2019-06-23",
#                     8
#                 ],
#                 [
#                     "2019-06-30",
#                     9
#                 ],
#                 [
#                     "2019-07-07",
#                     12
#                 ],
#                 [
#                     "2019-07-14",
#                     11
#                 ],
#                 [
#                     "2019-07-21",
#                     8
#                 ],
#                 [
#                     "2019-07-28",
#                     5
#                 ],
#                 [
#                     "2019-08-04",
#                     8
#                 ],
#                 [
#                     "2019-08-11",
#                     8
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 6,
#                     "opacity": 0.7,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1932331
#         },
#         {
#             "type": "line",
#             "name": "\uc57c\ub098\ub450",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2019-01-06",
#                     100
#                 ],
#                 [
#                     "2019-01-13",
#                     93
#                 ],
#                 [
#                     "2019-01-20",
#                     66
#                 ],
#                 [
#                     "2019-01-27",
#                     76
#                 ],
#                 [
#                     "2019-02-03",
#                     83
#                 ],
#                 [
#                     "2019-02-10",
#                     79
#                 ],
#                 [
#                     "2019-02-17",
#                     72
#                 ],
#                 [
#                     "2019-02-24",
#                     62
#                 ],
#                 [
#                     "2019-03-03",
#                     70
#                 ],
#                 [
#                     "2019-03-10",
#                     52
#                 ],
#                 [
#                     "2019-03-17",
#                     69
#                 ],
#                 [
#                     "2019-03-24",
#                     58
#                 ],
#                 [
#                     "2019-03-31",
#                     41
#                 ],
#                 [
#                     "2019-04-07",
#                     48
#                 ],
#                 [
#                     "2019-04-14",
#                     42
#                 ],
#                 [
#                     "2019-04-21",
#                     48
#                 ],
#                 [
#                     "2019-04-28",
#                     36
#                 ],
#                 [
#                     "2019-05-05",
#                     39
#                 ],
#                 [
#                     "2019-05-12",
#                     50
#                 ],
